# %% [markdown]
# # Group 2604 Members
#
# | Name | Family Name | Matriculation Number |
# |------|-------------|----------------------|
# | Luca | Di Turi | 2196579 |
# | Alessandro | Turino | 2205737 |
# | Mattia | Ziglioli | 2198835 |
# | Andrea | Marchetti | 2197526 |

# %%
#In the exercise solutions we kept the same dataset used during the lesson, i.e. the one dimensional timeserie with 3 different signal classes.

# %%
#Only in the first exercise we use a 2D CNN with Conv2D.

# %% [markdown]
# ### CNNs applied to time series

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import  Conv1D, Conv2D, AveragePooling1D, AveragePooling2D, MaxPooling1D, MaxPooling2D,GlobalMaxPooling1D
from tensorflow.keras.utils import to_categorical

# %run plot.py
#%run plot1.py   #same as plo.py but allows to visualize more data
# Out:
# 2026-03-19 19:40:44.078067: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-19 19:40:44.124769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX_VNNI, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_ts_L60_Z12_A500_DX50_bias5_N10000.dat'

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
#x50 = np.loadtxt('DATA/x_ts_L60_Z12_A50_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x100 = np.loadtxt('DATA/x_ts_L60_Z12_A100_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x200 = np.loadtxt('DATA/x_ts_L60_Z12_A200_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x300 = np.loadtxt('DATA/x_ts_L60_Z12_A300_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x400 = np.loadtxt('DATA/x_ts_L60_Z12_A400_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
# number of samples, number of features
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1. # y contains one-hot encoding
# Out:
# data:  10000

# %% [markdown]
# ### Split train-validation and rescale

# %%
# split into training and validation sets
def split(x, y, N, L, n_class, print_opt = False):
    perc_train=0.8
    N_train = int(perc_train*N)
    x_train = x[:N_train]
    y_train = y[:N_train]
    x_val = x[N_train:]
    y_val = y[N_train:]
    N_val = len(x_val)
        
    #remove average value of each sample from its values
    xm_train = x_train.mean(axis=1)
    std_train = x_train.std(axis=1)
    xm_val = x_val.mean(axis=1)
    std_val = x_val.std(axis=1)

    # rescale with variance on the training set
    for i in range(N_train):
        #x_train[i] = (x_train[i]-xm_train[i])/ std_train[i] #not good, std_train is very variable across samples
         #x_train[i] = (x_train[i]-xm_train[i])/ 400 #crude rescaling, variance should be used
         x_train[i] = (x_train[i]-xm_train[i])/ std_train.mean(axis=0)
    for i in range(N_val):
        #x_val[i] = (x_val[i]-xm_val[i])/ std_val[i]
        #x_val[i] = (x_val[i]-xm_val[i])/ 400
        x_val[i] = (x_val[i]-xm_val[i])/ std_val.mean(axis=0)
    if (print_opt == 1):
        print(x_train.shape)
        print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)
        print('std_train average and mean:',max(std_train), min(std_train), std_train.mean(axis=0))
        print('std_val average and mean:',max(std_val), min(std_val), std_val.mean(axis=0))
        Show_data(x_train,L,"rescaled train data")
        Show_data(x_val,L,"rescaled validation data")
        
    # Keras wants an additional dimension with a 1 at the end
    x_train = x_train.reshape(x_train.shape[0], L, 1)
    x_val =  x_val.reshape(x_val.shape[0], L, 1)
    input_shape = (L, 1) # number of features, number of channels (1 for 1D data)
    return x_train, x_val, y_train, y_val, input_shape
#

# %%
x_train, x_val, y_train, y_val, input_shape = split(x, y, N, L, n_class, True)     #set the last var. to 1 to print and show some features of the split dataset (0 to hide them)


#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")
# Out:
# (8000, 60)
# N_train= 8000   N_val= 2000   L= 60   n_class= 3
# std_train average and mean: 588.25397835931 44.84287073276593 201.46657645528722
# std_val average and mean: 569.9090424503428 55.06717110341998 201.92178219610327

# %% [markdown]
# ## Convolutional NN (definition and initialization of the different models)

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

def NN(input_shape, NCONV=1, NF=5, regularizer=2, lambda_par=0.2, print_opt=False, n_class=3):
    
    if regularizer == 1:
        reg = tf.keras.regularizers.l1(lambda_par)
    elif regularizer == 2:
        reg = tf.keras.regularizers.l2(lambda_par)
    elif regularizer == 3:
        reg = tf.keras.regularizers.l1_l2(lambda_par)
    
    ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None)

    model = Sequential()

    if NCONV == 1:
        model.add(Conv1D(filters=NF, kernel_size=11,
                         kernel_initializer=ini,
                         kernel_regularizer=reg,
                         activation='relu',
                         input_shape=input_shape))
        model.add(AveragePooling1D(5))
        model.add(Conv1D(filters=5, kernel_size=7, activation='relu'))
        model.add(Flatten())
        model.add(Dense(12, activation='relu'))
        model.add(Dropout(0.2))

    if NCONV == 2:
        model.add(Conv1D(filters=NF, kernel_size=11,
                         kernel_initializer=ini,
                         kernel_regularizer=reg,
                         activation='relu', input_shape=input_shape))
        model.add(AveragePooling1D(5))
        model.add(Flatten())
        model.add(Dense(9, activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(6, activation='relu'))
        model.add(Dropout(0.2))

    if NCONV == 3:
        model.add(Conv1D(filters=6, kernel_size=3,
                         kernel_initializer=ini,
                         kernel_regularizer=reg,
                         activation='relu',
                         input_shape=input_shape))
        model.add(Conv1D(filters=8, kernel_size=9, activation='relu'))
        model.add(Conv1D(filters=4, kernel_size=3, activation='relu'))
        model.add(GlobalMaxPooling1D())
        model.add(Flatten())

    if NCONV == 4:
      #2D CNN
        reg = tf.keras.regularizers.l2(0.001)
        model.add(Conv2D(filters=NF, kernel_size=(11, 2),
                         kernel_initializer=ini,
                         kernel_regularizer=reg,
                         activation='relu',
                         input_shape=input_shape))   
        model.add(AveragePooling2D(pool_size=(5, 1)))
        model.add(Conv2D(filters=5, kernel_size=(7, 1), activation='relu'))
        model.add(Flatten())
        model.add(Dense(12, activation='relu'))
        model.add(Dropout(0.2))

    
    model.add(Dense(n_class, activation='softmax'))

    if print_opt:
        print('----- Model', NCONV, '-----')
        print(model.summary())

    opt = tf.keras.optimizers.Adam()
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=opt, metrics=['accuracy'])
    return model, NCONV

# %%
model, NCONV = NN(input_shape, NCONV=1, print_opt = True)
# Out:
# ----- Model 1 -----
# /home/turino/anaconda3/envs/keras/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 50, 5)          │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 10, 5)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 4, 5)           │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │           252 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 531 (2.07 KB)
#  Trainable params: 531 (2.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.layers
# Out:
# [<Conv1D name=conv1d, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_1, built=True>,
#  <Flatten name=flatten, built=True>,
#  <Dense name=dense, built=True>,
#  <Dropout name=dropout, built=True>,
#  <Dense name=dense_1, built=True>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0] # weights
    print(w.shape)
    wT=w.T
    print(wT.shape)
    M=len(wT)
    b = model.layers[l].get_weights()[1] # bias
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()

# %%
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
#This cell updates the weights/biases of the CNN

# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 150

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=0, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()

# %%
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
opt2 = tf.keras.optimizers.Adam()   # NEW optimizer instance
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt2,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 150

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/150
# 40/40 - 2s - 38ms/step - accuracy: 0.3519 - loss: 1.1113 - val_accuracy: 0.3855 - val_loss: 1.0978
# Epoch 2/150
# 40/40 - 0s - 6ms/step - accuracy: 0.4166 - loss: 1.0844 - val_accuracy: 0.4665 - val_loss: 1.0623
# Epoch 3/150
# 40/40 - 0s - 7ms/step - accuracy: 0.5433 - loss: 1.0212 - val_accuracy: 0.6325 - val_loss: 0.9496
# Epoch 4/150
# 40/40 - 0s - 7ms/step - accuracy: 0.6470 - loss: 0.8814 - val_accuracy: 0.7555 - val_loss: 0.7851
# Epoch 5/150
# 40/40 - 0s - 8ms/step - accuracy: 0.7079 - loss: 0.7492 - val_accuracy: 0.7990 - val_loss: 0.6668
# Epoch 6/150
# 40/40 - 0s - 7ms/step - accuracy: 0.7569 - loss: 0.6607 - val_accuracy: 0.8215 - val_loss: 0.5906
# Epoch 7/150
# 40/40 - 0s - 7ms/step - accuracy: 0.7862 - loss: 0.5990 - val_accuracy: 0.8410 - val_loss: 0.5302
# Epoch 8/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8160 - loss: 0.5456 - val_accuracy: 0.8590 - val_loss: 0.4825
# Epoch 9/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8367 - loss: 0.5015 - val_accuracy: 0.8740 - val_loss: 0.4418
# Epoch 10/150
# 40/40 - 0s - 8ms/step - accuracy: 0.8526 - loss: 0.4732 - val_accuracy: 0.8830 - val_loss: 0.4101
# Epoch 11/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8677 - loss: 0.4387 - val_accuracy: 0.8950 - val_loss: 0.3826
# Epoch 12/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8751 - loss: 0.4130 - val_accuracy: 0.9055 - val_loss: 0.3612
# Epoch 13/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8848 - loss: 0.3947 - val_accuracy: 0.9080 - val_loss: 0.3409
# Epoch 14/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8919 - loss: 0.3698 - val_accuracy: 0.9120 - val_loss: 0.3228
# Epoch 15/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8986 - loss: 0.3518 - val_accuracy: 0.9145 - val_loss: 0.3098
# Epoch 16/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9022 - loss: 0.3412 - val_accuracy: 0.9220 - val_loss: 0.2961
# Epoch 17/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9051 - loss: 0.3299 - val_accuracy: 0.9250 - val_loss: 0.2841
# Epoch 18/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9130 - loss: 0.3143 - val_accuracy: 0.9260 - val_loss: 0.2743
# Epoch 19/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9130 - loss: 0.3058 - val_accuracy: 0.9285 - val_loss: 0.2650
# Epoch 20/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9215 - loss: 0.2958 - val_accuracy: 0.9300 - val_loss: 0.2560
# Epoch 21/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9246 - loss: 0.2810 - val_accuracy: 0.9325 - val_loss: 0.2481
# Epoch 22/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9236 - loss: 0.2852 - val_accuracy: 0.9365 - val_loss: 0.2406
# Epoch 23/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9311 - loss: 0.2692 - val_accuracy: 0.9350 - val_loss: 0.2354
# Epoch 24/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9310 - loss: 0.2619 - val_accuracy: 0.9380 - val_loss: 0.2297
# Epoch 25/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9301 - loss: 0.2585 - val_accuracy: 0.9400 - val_loss: 0.2227
# Epoch 26/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9359 - loss: 0.2486 - val_accuracy: 0.9415 - val_loss: 0.2187
# Epoch 27/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9374 - loss: 0.2432 - val_accuracy: 0.9405 - val_loss: 0.2127
# Epoch 28/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9429 - loss: 0.2328 - val_accuracy: 0.9415 - val_loss: 0.2087
# Epoch 29/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9441 - loss: 0.2268 - val_accuracy: 0.9450 - val_loss: 0.2028
# Epoch 30/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9442 - loss: 0.2254 - val_accuracy: 0.9455 - val_loss: 0.1999
# Epoch 31/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9430 - loss: 0.2186 - val_accuracy: 0.9465 - val_loss: 0.1934
# Epoch 32/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9452 - loss: 0.2139 - val_accuracy: 0.9480 - val_loss: 0.1880
# Epoch 33/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9473 - loss: 0.2041 - val_accuracy: 0.9510 - val_loss: 0.1849
# Epoch 34/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9479 - loss: 0.2081 - val_accuracy: 0.9510 - val_loss: 0.1832
# Epoch 35/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.2014 - val_accuracy: 0.9505 - val_loss: 0.1801
# Epoch 36/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9515 - loss: 0.1979 - val_accuracy: 0.9525 - val_loss: 0.1749
# Epoch 37/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9523 - loss: 0.1921 - val_accuracy: 0.9510 - val_loss: 0.1717
# Epoch 38/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9566 - loss: 0.1877 - val_accuracy: 0.9535 - val_loss: 0.1674
# Epoch 39/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9542 - loss: 0.1848 - val_accuracy: 0.9535 - val_loss: 0.1661
# Epoch 40/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9523 - loss: 0.1882 - val_accuracy: 0.9535 - val_loss: 0.1630
# Epoch 41/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9563 - loss: 0.1803 - val_accuracy: 0.9575 - val_loss: 0.1595
# Epoch 42/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9580 - loss: 0.1708 - val_accuracy: 0.9590 - val_loss: 0.1569
# Epoch 43/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9590 - loss: 0.1751 - val_accuracy: 0.9570 - val_loss: 0.1571
# Epoch 44/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9603 - loss: 0.1675 - val_accuracy: 0.9555 - val_loss: 0.1570
# Epoch 45/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9578 - loss: 0.1702 - val_accuracy: 0.9600 - val_loss: 0.1514
# Epoch 46/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9619 - loss: 0.1664 - val_accuracy: 0.9620 - val_loss: 0.1468
# Epoch 47/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9604 - loss: 0.1634 - val_accuracy: 0.9580 - val_loss: 0.1491
# Epoch 48/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9616 - loss: 0.1604 - val_accuracy: 0.9615 - val_loss: 0.1439
# Epoch 49/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9619 - loss: 0.1597 - val_accuracy: 0.9605 - val_loss: 0.1431
# Epoch 50/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9631 - loss: 0.1591 - val_accuracy: 0.9650 - val_loss: 0.1384
# Epoch 51/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9655 - loss: 0.1516 - val_accuracy: 0.9625 - val_loss: 0.1383
# Epoch 52/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9638 - loss: 0.1536 - val_accuracy: 0.9655 - val_loss: 0.1356
# Epoch 53/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9634 - loss: 0.1520 - val_accuracy: 0.9670 - val_loss: 0.1331
# Epoch 54/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9672 - loss: 0.1418 - val_accuracy: 0.9645 - val_loss: 0.1354
# Epoch 55/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9668 - loss: 0.1449 - val_accuracy: 0.9665 - val_loss: 0.1325
# Epoch 56/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9664 - loss: 0.1426 - val_accuracy: 0.9670 - val_loss: 0.1311
# Epoch 57/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9686 - loss: 0.1390 - val_accuracy: 0.9680 - val_loss: 0.1267
# Epoch 58/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9703 - loss: 0.1350 - val_accuracy: 0.9680 - val_loss: 0.1281
# Epoch 59/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9695 - loss: 0.1349 - val_accuracy: 0.9685 - val_loss: 0.1264
# Epoch 60/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9670 - loss: 0.1353 - val_accuracy: 0.9695 - val_loss: 0.1213
# Epoch 61/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9707 - loss: 0.1297 - val_accuracy: 0.9705 - val_loss: 0.1193
# Epoch 62/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9681 - loss: 0.1317 - val_accuracy: 0.9680 - val_loss: 0.1226
# Epoch 63/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9689 - loss: 0.1295 - val_accuracy: 0.9695 - val_loss: 0.1186
# Epoch 64/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9709 - loss: 0.1284 - val_accuracy: 0.9690 - val_loss: 0.1190
# Epoch 65/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9709 - loss: 0.1271 - val_accuracy: 0.9690 - val_loss: 0.1166
# Epoch 66/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9714 - loss: 0.1253 - val_accuracy: 0.9710 - val_loss: 0.1152
# Epoch 67/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9729 - loss: 0.1185 - val_accuracy: 0.9710 - val_loss: 0.1121
# Epoch 68/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9721 - loss: 0.1205 - val_accuracy: 0.9715 - val_loss: 0.1119
# Epoch 69/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9726 - loss: 0.1160 - val_accuracy: 0.9710 - val_loss: 0.1117
# Epoch 70/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9740 - loss: 0.1175 - val_accuracy: 0.9710 - val_loss: 0.1101
# Epoch 71/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9736 - loss: 0.1165 - val_accuracy: 0.9715 - val_loss: 0.1093
# Epoch 72/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9743 - loss: 0.1147 - val_accuracy: 0.9710 - val_loss: 0.1095
# Epoch 73/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9703 - loss: 0.1206 - val_accuracy: 0.9715 - val_loss: 0.1072
# Epoch 74/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9762 - loss: 0.1104 - val_accuracy: 0.9700 - val_loss: 0.1077
# Epoch 75/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9739 - loss: 0.1138 - val_accuracy: 0.9715 - val_loss: 0.1074
# Epoch 76/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9753 - loss: 0.1136 - val_accuracy: 0.9725 - val_loss: 0.1066
# Epoch 77/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9758 - loss: 0.1092 - val_accuracy: 0.9710 - val_loss: 0.1083
# Epoch 78/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9750 - loss: 0.1091 - val_accuracy: 0.9730 - val_loss: 0.1063
# Epoch 79/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9730 - loss: 0.1113 - val_accuracy: 0.9720 - val_loss: 0.1045
# Epoch 80/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9769 - loss: 0.1052 - val_accuracy: 0.9725 - val_loss: 0.1039
# Epoch 81/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9756 - loss: 0.1058 - val_accuracy: 0.9720 - val_loss: 0.1039
# Epoch 82/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9740 - loss: 0.1076 - val_accuracy: 0.9740 - val_loss: 0.1014
# Epoch 83/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9762 - loss: 0.1041 - val_accuracy: 0.9735 - val_loss: 0.1004
# Epoch 84/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9764 - loss: 0.1065 - val_accuracy: 0.9755 - val_loss: 0.0979
# Epoch 85/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9781 - loss: 0.1002 - val_accuracy: 0.9735 - val_loss: 0.0989
# Epoch 86/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9764 - loss: 0.1043 - val_accuracy: 0.9750 - val_loss: 0.0942
# Epoch 87/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9769 - loss: 0.0986 - val_accuracy: 0.9750 - val_loss: 0.0985
# Epoch 88/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9765 - loss: 0.1048 - val_accuracy: 0.9745 - val_loss: 0.0945
# Epoch 89/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9789 - loss: 0.0996 - val_accuracy: 0.9760 - val_loss: 0.0944
# Epoch 90/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.0989 - val_accuracy: 0.9760 - val_loss: 0.0931
# Epoch 91/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9774 - loss: 0.1004 - val_accuracy: 0.9735 - val_loss: 0.0954
# Epoch 92/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9774 - loss: 0.0970 - val_accuracy: 0.9760 - val_loss: 0.0924
# Epoch 93/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9785 - loss: 0.0966 - val_accuracy: 0.9765 - val_loss: 0.0923
# Epoch 94/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9784 - loss: 0.0971 - val_accuracy: 0.9745 - val_loss: 0.0933
# Epoch 95/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9784 - loss: 0.0959 - val_accuracy: 0.9765 - val_loss: 0.0917
# Epoch 96/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9781 - loss: 0.0937 - val_accuracy: 0.9775 - val_loss: 0.0909
# Epoch 97/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.0922 - val_accuracy: 0.9730 - val_loss: 0.0953
# Epoch 98/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9797 - loss: 0.0962 - val_accuracy: 0.9770 - val_loss: 0.0891
# Epoch 99/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9783 - loss: 0.0971 - val_accuracy: 0.9765 - val_loss: 0.0904
# Epoch 100/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9786 - loss: 0.0920 - val_accuracy: 0.9770 - val_loss: 0.0891
# Epoch 101/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9800 - loss: 0.0891 - val_accuracy: 0.9805 - val_loss: 0.0863
# Epoch 102/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9781 - loss: 0.0918 - val_accuracy: 0.9775 - val_loss: 0.0857
# Epoch 103/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9800 - loss: 0.0889 - val_accuracy: 0.9780 - val_loss: 0.0866
# Epoch 104/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9791 - loss: 0.0905 - val_accuracy: 0.9770 - val_loss: 0.0876
# Epoch 105/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9816 - loss: 0.0869 - val_accuracy: 0.9780 - val_loss: 0.0858
# Epoch 106/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9808 - loss: 0.0890 - val_accuracy: 0.9795 - val_loss: 0.0865
# Epoch 107/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9797 - loss: 0.0887 - val_accuracy: 0.9785 - val_loss: 0.0876
# Epoch 108/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9797 - loss: 0.0894 - val_accuracy: 0.9775 - val_loss: 0.0870
# Epoch 109/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9809 - loss: 0.0863 - val_accuracy: 0.9795 - val_loss: 0.0855
# Epoch 110/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9799 - loss: 0.0876 - val_accuracy: 0.9780 - val_loss: 0.0846
# Epoch 111/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9797 - loss: 0.0874 - val_accuracy: 0.9810 - val_loss: 0.0832
# Epoch 112/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9801 - loss: 0.0847 - val_accuracy: 0.9810 - val_loss: 0.0823
# Epoch 113/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9803 - loss: 0.0852 - val_accuracy: 0.9790 - val_loss: 0.0821
# Epoch 114/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9801 - loss: 0.0855 - val_accuracy: 0.9780 - val_loss: 0.0845
# Epoch 115/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9805 - loss: 0.0850 - val_accuracy: 0.9780 - val_loss: 0.0824
# Epoch 116/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9796 - loss: 0.0852 - val_accuracy: 0.9810 - val_loss: 0.0802
# Epoch 117/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.0849 - val_accuracy: 0.9810 - val_loss: 0.0803
# Epoch 118/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9815 - loss: 0.0812 - val_accuracy: 0.9800 - val_loss: 0.0800
# Epoch 119/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9804 - loss: 0.0855 - val_accuracy: 0.9815 - val_loss: 0.0796
# Epoch 120/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9804 - loss: 0.0848 - val_accuracy: 0.9795 - val_loss: 0.0823
# Epoch 121/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9787 - loss: 0.0837 - val_accuracy: 0.9810 - val_loss: 0.0782
# Epoch 122/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9803 - loss: 0.0817 - val_accuracy: 0.9800 - val_loss: 0.0784
# Epoch 123/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9815 - loss: 0.0803 - val_accuracy: 0.9830 - val_loss: 0.0757
# Epoch 124/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9815 - loss: 0.0808 - val_accuracy: 0.9805 - val_loss: 0.0768
# Epoch 125/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9810 - loss: 0.0817 - val_accuracy: 0.9800 - val_loss: 0.0784
# Epoch 126/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9818 - loss: 0.0829 - val_accuracy: 0.9815 - val_loss: 0.0787
# Epoch 127/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9825 - loss: 0.0818 - val_accuracy: 0.9810 - val_loss: 0.0788
# Epoch 128/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9830 - loss: 0.0780 - val_accuracy: 0.9820 - val_loss: 0.0757
# Epoch 129/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9835 - loss: 0.0773 - val_accuracy: 0.9825 - val_loss: 0.0756
# Epoch 130/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9826 - loss: 0.0745 - val_accuracy: 0.9800 - val_loss: 0.0774
# Epoch 131/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9822 - loss: 0.0795 - val_accuracy: 0.9805 - val_loss: 0.0774
# Epoch 132/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9803 - loss: 0.0799 - val_accuracy: 0.9800 - val_loss: 0.0795
# Epoch 133/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9815 - loss: 0.0780 - val_accuracy: 0.9815 - val_loss: 0.0753
# Epoch 134/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9846 - loss: 0.0745 - val_accuracy: 0.9805 - val_loss: 0.0764
# Epoch 135/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9845 - loss: 0.0736 - val_accuracy: 0.9810 - val_loss: 0.0769
# Epoch 136/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9826 - loss: 0.0760 - val_accuracy: 0.9815 - val_loss: 0.0761
# Epoch 137/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9833 - loss: 0.0765 - val_accuracy: 0.9810 - val_loss: 0.0744
# Epoch 138/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9816 - loss: 0.0779 - val_accuracy: 0.9825 - val_loss: 0.0744
# Epoch 139/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9831 - loss: 0.0740 - val_accuracy: 0.9815 - val_loss: 0.0745
# Epoch 140/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9833 - loss: 0.0747 - val_accuracy: 0.9815 - val_loss: 0.0729
# Epoch 141/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9821 - loss: 0.0743 - val_accuracy: 0.9810 - val_loss: 0.0764
# Epoch 142/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9844 - loss: 0.0719 - val_accuracy: 0.9820 - val_loss: 0.0736
# Epoch 143/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9852 - loss: 0.0708 - val_accuracy: 0.9815 - val_loss: 0.0751
# Epoch 144/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9825 - loss: 0.0746 - val_accuracy: 0.9810 - val_loss: 0.0746
# Epoch 145/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9850 - loss: 0.0723 - val_accuracy: 0.9810 - val_loss: 0.0732
# Epoch 146/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9844 - loss: 0.0732 - val_accuracy: 0.9820 - val_loss: 0.0733
# Epoch 147/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9833 - loss: 0.0710 - val_accuracy: 0.9830 - val_loss: 0.0690
# Epoch 148/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9835 - loss: 0.0735 - val_accuracy: 0.9845 - val_loss: 0.0715
# Epoch 149/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9837 - loss: 0.0732 - val_accuracy: 0.9825 - val_loss: 0.0705
# Epoch 150/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9808 - loss: 0.0781 - val_accuracy: 0.9830 - val_loss: 0.0721

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# confusion table: compare true labels with predicted ones
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"] # from labels y 
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 1. Two dimensional CNN
#
# We now perform CNN on a **2-dimensional** dataset (D=2), scanning the two time series in parallel. Similarly to the lesson, we have introduced a pattern that affects both time series around the same position in
# the sample. The pattern is similar to the previous dataset, except that here the sine-induced bump is always positive and never negative. This time we have 4 classes: no bump in either signal, a bump only in the first, a bump only in the second, and finally a bump in both.

# %% [markdown]
# ### Create Data
#
# We generate a new dataset for this exercise. We create a new model using Conv2D, defined in the previous function NN (look at the start of the notebook).We noticed that the model did not learn well with such a high lambda: it would only pick up meaningful patterns after a large number of epochs $n_{epoch}=100 $. We therefore reduced it by one order of magnitude $\lambda = 0.001$

# %%
np.random.seed(12345)

Z    = 12    
A    = 500    
L    = 60     
N    = 10000 
DX   = 50     
bias = 5      
n_class = 4

jump    = lambda drift, stdev: int(np.random.normal(drift, stdev))
pattern = lambda j, z, a:     int(a * np.sin((np.pi * j) / z))

def make_series(add_bump=False):
    ts = np.zeros(L)
    for j in range(1, L):
        ts[j] = ts[j-1] + jump(bias, DX)
    if add_bump:
        j0 = np.random.randint(0, L - Z)          
        for j in range(Z):
            ts[j0 + j] += pattern(j, Z, A)        
    return ts

x = np.zeros((N, L, 2))
y = np.zeros(N, dtype=int)


for i in range(N):
    cls = i % 4                                    
    y[i] = cls

    bump1 = cls in (1, 3)                          
    bump2 = cls in (2, 3)                          

    x[i, :, 0] = make_series(add_bump=bump1)
    x[i, :, 1] = make_series(add_bump=bump2)

# %%
# save
str0   = f'ts2D_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.dat'  
# !mkdir -p DATA
fnamey = 'DATA/y_' + str0
str0 = f'ts2D_L{L}_Z{Z}_A{A}_DX{DX}_bias{bias}_N{N}.dat'
np.savetxt(f'DATA/x_{str0}', x.reshape(N, -1), fmt='%d')
np.savetxt(f'DATA/y_{str0}', y,                fmt='%d')

# %% [markdown]
# We want to evaluate how the CNN work for different values of the time offset $\Delta T$, so we define an array with different scales of time-offset:

# %% [markdown]
# ### Read the new generated data

# %%
n_class = 4    # y.argmax() - y.argmin() +1
x_second_time_series= np.loadtxt('DATA/x_ts2D_L60_Z12_A500_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)

x_second_time_series = x_second_time_series.reshape(N, L, 2)

categ = np.loadtxt(fnamey, dtype=int)
y = to_categorical(categ, num_classes=n_class)   # più semplice

print(y.shape)   # (10000, 4)
# Out:
# (10000, 4)

# %%
def split_2D(x, y, N, L, n_class, print_opt=False):
    perc_train = 0.8
    N_train = int(perc_train * N)
    x_train = x[:N_train]
    y_train = y[:N_train]
    x_val   = x[N_train:]
    y_val   = y[N_train:]
    N_val   = len(x_val)

    # mean and std computed per sample per channel: shape (n_samples, 2)
    xm_train  = x_train.mean(axis=1)   # shape (N_train, 2)
    std_train = x_train.std(axis=1)    # shape (N_train, 2)
    xm_val    = x_val.mean(axis=1)     # shape (N_val, 2)
    std_val   = x_val.std(axis=1)      # shape (N_val, 2)

    # normalize each channel independently
    std_mean = std_train.mean(axis=0)  # shape (2,) — one std per channel
    for i in range(N_train):
        x_train[i] = (x_train[i] - xm_train[i]) / std_mean
    for i in range(N_val):
        x_val[i] = (x_val[i] - xm_val[i]) / std_mean

    # shape is already (nc_samples, L, 2) — no reshape needed
    input_shape = (L, 2, 1)

    return x_train, x_val, y_train, y_val, input_shape

# %%
print(fnamey)                                    # quale file sta caricando?
categ = np.loadtxt(fnamey, dtype=int)
print(categ.shape)                               # (10000,)
print(np.unique(categ, return_counts=True))      # deve dare [0,1,2,3] × 250
# Out:
# DATA/y_ts2D_L60_Z12_A500_DX50_bias5_N10000.dat
# (10000,)
# (array([0, 1, 2, 3]), array([2500, 2500, 2500, 2500]))

# %% [markdown]
# Now we use a model_2D, one for each $\Delta T$

# %%
BATCH_SIZE = 200
EPOCHS = 150
x =x_second_time_series
results = {}
n_class = 4     
N_t = len(x)

x_train_t, x_val_t, y_train_t, y_val_t,input_shape = split_2D(x, y, N_t, L, n_class)
x_train_t = x_train_t[..., np.newaxis]  
x_val_t   = x_val_t[..., np.newaxis] 
np.random.seed(12345)
tf_r.set_seed(12345)
model_2D, _ = NN(input_shape, NCONV=4, print_opt = True, n_class=4)

fit_T = model_2D.fit(x_train_t, y_train_t,
                        batch_size=BATCH_SIZE, epochs=EPOCHS,
                        validation_data=(x_val_t, y_val_t),
                        verbose=0, shuffle=True)

results[0] = {'fit': fit_T, 'model': model_2D,
                  'x_val': x_val_t, 'y_val': y_val_t}
# Out:
# ----- Model 4 -----
# /home/turino/anaconda3/envs/keras/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 50, 1, 5)       │           115 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 10, 1, 5)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 1, 5)        │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 12)             │           252 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │            52 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 599 (2.34 KB)
#  Trainable params: 599 (2.34 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# All models use the same amount of parameters (less than 600). We expect that the results will be pretty similar.

# %%
def show_confusion_matrix2D(validations, predictions, label="Model"):

    LABELS = ['absent', 'only1', 'only2', 'both']
    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# Learning curves
fig, AX = plt.subplots(1, 2, figsize=(14, 5))
fit_A = results[0]['fit']
AX[0].plot(fit_A.history['accuracy'],     color="red", ls='-',  label=f' train')
AX[0].plot(fit_A.history['val_accuracy'], color="blue", ls='--', label=f'val')
AX[1].plot(fit_A.history['loss'],         color="red", ls='-',  label=f'train')
AX[1].plot(fit_A.history['val_loss'],     color="blue", ls='--', label=f'val')

AX[0].axhline(1/3, color='gray', ls=':', label='random')
AX[0].set_title('Accuracy vs Epoch'); AX[0].set_xlabel('Epoch'); AX[0].set_ylabel('Accuracy')
AX[0].set_ylim([0, 1]); AX[0].legend(fontsize=10)
AX[1].set_title('Loss vs Epoch');     AX[1].set_xlabel('Epoch'); AX[1].set_ylabel('Loss')
AX[1].legend(fontsize=10)
plt.tight_layout()
plt.show()

# Confusion matrices
for t in [0]:
    y_pred = results[t]['model'].predict(results[t]['x_val'], verbose=0)
    show_confusion_matrix2D(
    np.argmax(y_val_t, axis=1),
    np.argmax(y_pred,  axis=1),
    label='Conv2D - 4 classes'
)

# %% [markdown]
# ### Results
#
# As we can see from the confusion matrix, the model achieves an overall test accuracy of **98.5%**, with per-class accuracies of **98.6%** (absent), **99.2%** (only1), **98.4%** (only2), and 97.8% (both). This confirms that misclassifications are rare and evenly distributed, with no systematic bias toward any particular class. The Conv2D architecture handles this task very well

# %% [markdown]
# ## 2. Performance Analysis: SNR Sensitivity Study
#
# We evaluate the CNN's robustness by varying the **Signal-to-Noise Ratio (SNR)**. While keeping the Gaussian noise constant ($\mu=5, \sigma=50$), we test the model's accuracy across three different pattern amplitudes:
#
# * **High SNR:** $A = 200$
# * **Mid SNR:** $A = 100$
# * **Low SNR:** $A = 50$ (Signal amplitude equal to noise $\sigma$)
#
# The goal is to identify the threshold where the pattern becomes indistinguishable from the background random walk.

# %%
help(split)
# Out:
# Help on function split in module __main__:
#
# split(x, y, N, L, n_class, print_opt=False)
#     # split into training and validation sets

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_ts_L60_Z12_A500_DX50_bias5_N10000.dat'

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
#x50 = np.loadtxt('DATA/x_ts_L60_Z12_A50_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x100 = np.loadtxt('DATA/x_ts_L60_Z12_A100_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x200 = np.loadtxt('DATA/x_ts_L60_Z12_A200_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x300 = np.loadtxt('DATA/x_ts_L60_Z12_A300_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
x400 = np.loadtxt('DATA/x_ts_L60_Z12_A400_DX50_bias5_N10000.dat', delimiter=" ",dtype=float)
# number of samples, number of features
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1. # y contains one-hot encoding
# Out:
# data:  10000

# %%
amplitudes = [100, 200, 300, 400]
x_datasets = [x100, x200, x300, x400]
BATCH_SIZE = 200
EPOCHS = 150
n_class=3
results = {}

for A, x_A in zip(amplitudes, x_datasets):
    x_A = x_A.copy()
    N_A = len(x_A)

    x_train_A, x_val_A, y_train_A, y_val_A, input_shape = split(x_A, y, N_A, L, n_class)

    np.random.seed(12345)
    tf_r.set_seed(12345)
    model_A, _ = NN(input_shape)

    fit_A = model_A.fit(x_train_A, y_train_A,
                        batch_size=BATCH_SIZE, epochs=EPOCHS,
                        validation_data=(x_val_A, y_val_A),
                        verbose=0, shuffle=True)

    results[A] = {'fit': fit_A, 'model': model_A,
                  'x_val': x_val_A, 'y_val': y_val_A}

# Learning curves
colors = {100: 'tab:red', 200: 'tab:orange', 300: 'tab:green', 400: 'tab:blue'}

fig, AX = plt.subplots(1, 2, figsize=(14, 5))
for A in amplitudes:
    fit_A = results[A]['fit']
    AX[0].plot(fit_A.history['accuracy'],     color=colors[A], ls='-',  label=f'A={A} train')
    AX[0].plot(fit_A.history['val_accuracy'], color=colors[A], ls='--', label=f'A={A} val')
    AX[1].plot(fit_A.history['loss'],         color=colors[A], ls='-',  label=f'A={A} train')
    AX[1].plot(fit_A.history['val_loss'],     color=colors[A], ls='--', label=f'A={A} val')

AX[0].axhline(1/3, color='gray', ls=':', label='random')
AX[0].set_title('Accuracy vs Epoch'); AX[0].set_xlabel('Epoch'); AX[0].set_ylabel('Accuracy')
AX[0].set_ylim([0, 1]); AX[0].legend(fontsize=10)
AX[1].set_title('Loss vs Epoch');     AX[1].set_xlabel('Epoch'); AX[1].set_ylabel('Loss')
AX[1].legend(fontsize=10)
plt.tight_layout()
plt.show()

# Confusion matrices
for A in amplitudes:
    y_pred_A = results[A]['model'].predict(results[A]['x_val'], verbose=0)
    show_confusion_matrix(np.argmax(results[A]['y_val'], axis=1),
                          np.argmax(y_pred_A, axis=1),
                          label=f"A={A}")

# %% [markdown]
# ## results:
#
# As the amplitude $A$ increases, the CNN performance improves consistently. At **A = 100** the model
# barely exceeds the random baseline (~40% accuracy), while at **A = 400** it reaches ~95%.
# The confusion matrices confirm this trend: at low $A$ misclassifications are spread across all classes,
# whereas at **A = 300** and **A = 400** the diagonal becomes strongly dominant, indicating reliable
# separation of all three classes. No significant overfitting is observed at any amplitude.

# %% [markdown]
# ## 3.

# %% [markdown]
# ## 4. CNN modeled around the best one of 2020-2021
#
# The model uses **3 convolutional layers** (no pooling), with the intermediate Dense layer
# replaced by a **GlobalMaxPooling1D**, for a total of 579 trainable parameters:
#
# To allow a fair comparison with the results seen in class, the model was trained with
# **A=500 samples** and **L2 regularization**.

# %%
if x.ndim == 3:
    x = x[:, :, 0]  # or x.reshape(N, L) if both channels are the same

print("x.shape after fix:", x.shape)  # should be (10000, 60)
# Out:
# x.shape after fix: (10000, 60)

# %%
BATCH_SIZE = 200
EPOCHS = 150
np.random.seed(12345)
tf_r.set_seed(12345)

x_train, x_val, y_train, y_val, input_shape = split(x, y, N, L, n_class)

model4, _ = NN(input_shape, NCONV = 3)

fit = model4.fit(x_train, y_train,
                        batch_size=BATCH_SIZE, epochs=EPOCHS,
                        validation_data=(x_val, y_val),
                        verbose=0, shuffle=True)
# Out:
# /home/turino/anaconda3/envs/keras/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
Show_history(fit)

y_pred_val = model4.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val, label = 'Model 2020-2021')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## results:
#
# The 2020-2021 model outperforms the lesson model on all metrics:
#
# - **Misclassified samples:** 27 vs 42 — a 36% reduction in errors
# - **Accuracy:** ~ 99% vs ~ 98%, with a lower final loss (~ 0.04 vs ~ 0.07)
# - **Convergence:** ~ 30 epochs vs ~ 75 epochs
#
# This improvement is likely due to two key architectural choices:
# - **GlobalMaxPooling1D** makes the model invariant to the position of the pattern within the sequence, which is beneficial when the 12-step pattern can appear anywhere in the signal
# - **No intermediate pooling** preserves the full temporal resolution across all convolutional layers, allowing richer feature extraction before the final classification
